# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\m.maroof\miniconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\m.maroof\miniconda3\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\m.maroof\miniconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\m.maroof\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\m.maroof\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\m.maroof\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\m.maroof\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\m.maroof\miniconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\m.maroof\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\m.maroof\miniconda3\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\m.maroof\miniconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\m.maroof\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\m.maroof\miniconda3\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\m.maroof\miniconda3\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\m.maroof\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data\DailyDelhiClimateTrain.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\M.Maroof\AppData\Local\Temp\ipykernel_2656\746331879.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("Data\DailyDelhiClimateTrain.csv")

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.isnull().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.set_index("date",inplace=True)

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
plt.figure(figsize=(12,5))
plt.plot(df.index, df['meantemp'])
plt.title("Daily Mean Temperature in Delhi")
plt.xlabel("Date")
plt.ylabel("Mean Temperature (°C)")
plt.grid(True)
plt.show()

# %%
monthly = df['meantemp'].resample('M').mean()
plt.figure(figsize=(12,5))
plt.plot(monthly.index, monthly, marker='o')
plt.title("Monthly Average Temperature")
plt.show()
# Out:
# C:\Users\M.Maroof\AppData\Local\Temp\ipykernel_2656\2833003168.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = df['meantemp'].resample('M').mean()

# %%
rolling = df['meantemp'].rolling(window=30).mean()
plt.figure(figsize=(12,5))
plt.plot(df.index, df['meantemp'], alpha=0.4, label='Raw')
plt.plot(rolling.index, rolling, label='30-day MA', linewidth=2)
plt.legend()
plt.show()

# %%
df['meantemp'].interpolate(method='time', inplace=True)
# Out:
# C:\Users\M.Maroof\AppData\Local\Temp\ipykernel_2656\671003682.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['meantemp'].interpolate(method='time', inplace=True)
